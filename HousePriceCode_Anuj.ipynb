# %%
print("We are setting up system")
# Out:
# We are setting up system

# %%
# Import libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import numpy as np
import pandas as pd
pd.set_option('max_columns', None)
pd.set_option('max_rows', 90)

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')

# %%
from sklearn.neighbors import KNeighborsRegressor
import scipy.stats
from sklearn.preprocessing import StandardScaler

from sklearn.model_selection import KFold, cross_val_score

# %%
from sklearn.linear_model import BayesianRidge, HuberRegressor, Ridge, OrthogonalMatchingPursuit


from sklearn.ensemble import GradientBoostingRegressor

# %%
#Reading files Train files 


train_data = pd.read_csv("train.csv")
train_data.head()
train_data.describe()

train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
# Id               1460 non-null int64
# MSSubClass       1460 non-null int64
# MSZoning         1460 non-null object
# LotFrontage      1201 non-null float64
# LotArea          1460 non-null int64
# Street           1460 non-null object
# Alley            91 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# RoofStyle        1460 non-null object
# ...

# %%
#checking number of NA in Train Data

train_data.isnull().sum().sum()  #number of NA
# Out:
# 6965

# %%
#saving target variable

target_sales = train_data['SalePrice']

# %%
target_sales
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
# 5       143000
# 6       307000
# 7       200000
# 8       129900
# 9       118000
# 10      129500
# 11      345000
# 12      144000
# 13      279500
# 14      157000
# 15      132000
# 16      149000
# 17       90000
# 18      159000
# 19      139000
# 20      325300
# 21      139400
# 22      230000
# 23      129900
# 24      154000
# 25      256300
# 26      134800
# 27      306000
# 28      207500
# 29       68500
# 30       40000
# 31      149350
# 32      179900
# 33      165500
# 34      277500
# 35      309000
# 36      145000
# 37      153000
# 38      109000
# 39       82000
# 40      160000
# 41      170000
# 42      144000
# 43      130250
# 44      141000
#          ...
# 1415    175900
# 1416    122500
# 1417    340000
# 1418    124000
# 1419    223000
# 1420    179900
# 1421    127500
# 1422    136500
# 1423    274970
# 1424    144000
# 1425    142000
# 1426    271000
# ...

# %%
#dropping target variable from train data since we not need it in Train

kaggle_train_data = train_data.drop(['Id', 'SalePrice'], axis=1)

# %%
kaggle_train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 79 columns):
# MSSubClass       1460 non-null int64
# MSZoning         1460 non-null object
# LotFrontage      1201 non-null float64
# LotArea          1460 non-null int64
# Street           1460 non-null object
# Alley            91 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# RoofStyle        1460 non-null object
# RoofMatl         1460 non-null object
# ...

# %%
kaggle_train_data.isnull().sum()
# Out:
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           37
# BsmtCond           37
# BsmtExposure       38
# BsmtFinType1       37
# BsmtFinSF1          0
# BsmtFinType2       38
# BsmtFinSF2          0
# BsmtUnfSF           0
# TotalBsmtSF         0
# Heating             0
# HeatingQC           0
# CentralAir          0
# ...

# %%
#Importing TEST Data and reading test data file
test_data = pd.read_csv("test.csv")

#dropping ID col from test data 

kaggle_test_data = test_data.drop('Id', axis=1)
kaggle_test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 79 columns):
# MSSubClass       1459 non-null int64
# MSZoning         1455 non-null object
# LotFrontage      1232 non-null float64
# LotArea          1459 non-null int64
# Street           1459 non-null object
# Alley            107 non-null object
# LotShape         1459 non-null object
# LandContour      1459 non-null object
# Utilities        1457 non-null object
# LotConfig        1459 non-null object
# LandSlope        1459 non-null object
# Neighborhood     1459 non-null object
# Condition1       1459 non-null object
# Condition2       1459 non-null object
# BldgType         1459 non-null object
# HouseStyle       1459 non-null object
# OverallQual      1459 non-null int64
# OverallCond      1459 non-null int64
# YearBuilt        1459 non-null int64
# YearRemodAdd     1459 non-null int64
# RoofStyle        1459 non-null object
# RoofMatl         1459 non-null object
# ...

# %%
test_data.isnull().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            4
# LotFrontage       227
# LotArea             0
# Street              0
# Alley            1352
# LotShape            0
# LandContour         0
# Utilities           2
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         1
# Exterior2nd         1
# MasVnrType         16
# MasVnrArea         15
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           44
# BsmtCond           45
# BsmtExposure       44
# BsmtFinType1       42
# BsmtFinSF1          1
# BsmtFinType2       42
# BsmtFinSF2          1
# BsmtUnfSF           1
# TotalBsmtSF         1
# Heating             0
# HeatingQC           0
# ...

# %%
test_ids = test_data['Id']

# %%
kaggle_test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 79 columns):
# MSSubClass       1459 non-null int64
# MSZoning         1455 non-null object
# LotFrontage      1232 non-null float64
# LotArea          1459 non-null int64
# Street           1459 non-null object
# Alley            107 non-null object
# LotShape         1459 non-null object
# LandContour      1459 non-null object
# Utilities        1457 non-null object
# LotConfig        1459 non-null object
# LandSlope        1459 non-null object
# Neighborhood     1459 non-null object
# Condition1       1459 non-null object
# Condition2       1459 non-null object
# BldgType         1459 non-null object
# HouseStyle       1459 non-null object
# OverallQual      1459 non-null int64
# OverallCond      1459 non-null int64
# YearBuilt        1459 non-null int64
# YearRemodAdd     1459 non-null int64
# RoofStyle        1459 non-null object
# RoofMatl         1459 non-null object
# ...

# %%
kaggle_combine_data = pd.concat([kaggle_train_data,kaggle_test_data],axis=0).reset_index(drop=True)

# %%
kaggle_combine_data_storage = kaggle_combine_data.copy()

# %%
kaggle_combine_data_storage.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2919 entries, 0 to 2918
# Data columns (total 79 columns):
# MSSubClass       2919 non-null int64
# MSZoning         2915 non-null object
# LotFrontage      2433 non-null float64
# LotArea          2919 non-null int64
# Street           2919 non-null object
# Alley            198 non-null object
# LotShape         2919 non-null object
# LandContour      2919 non-null object
# Utilities        2917 non-null object
# LotConfig        2919 non-null object
# LandSlope        2919 non-null object
# Neighborhood     2919 non-null object
# Condition1       2919 non-null object
# Condition2       2919 non-null object
# BldgType         2919 non-null object
# HouseStyle       2919 non-null object
# OverallQual      2919 non-null int64
# OverallCond      2919 non-null int64
# YearBuilt        2919 non-null int64
# YearRemodAdd     2919 non-null int64
# RoofStyle        2919 non-null object
# RoofMatl         2919 non-null object
# ...

# %%
kaggle_combine_data.select_dtypes(np.number)
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0             60         65.0     8450            7            5       2003
# 1             20         80.0     9600            6            8       1976
# 2             60         68.0    11250            7            5       2001
# 3             70         60.0     9550            7            5       1915
# 4             60         84.0    14260            8            5       2000
# 5             50         85.0    14115            5            5       1993
# 6             20         75.0    10084            8            5       2004
# 7             60          NaN    10382            7            6       1973
# 8             50         51.0     6120            7            5       1931
# 9            190         50.0     7420            5            6       1939
# 10            20         70.0    11200            5            5       1965
# ...

# %%
#converting MSSubClass into String ....Datatype conversion


kaggle_combine_data['MSSubClass'] = kaggle_combine_data['MSSubClass'].astype(str)

# %%
#treating missing Value Categorical 


# Impute using a constant value
for column in [
    'Alley',
    'BsmtQual',
    'BsmtCond',
    'BsmtExposure',
    'BsmtFinType1',
    'BsmtFinType2',
    'FireplaceQu',
    'GarageType',
    'GarageFinish',
    'GarageQual',
    'GarageCond',
    'PoolQC',
    'Fence',
    'MiscFeature'
]:
    kaggle_combine_data[column] = kaggle_combine_data[column].fillna("None")

# %%
# Impute using the mode
for column in [
    'MSZoning',
    'Utilities',
    'Exterior1st',
    'Exterior2nd',
    'MasVnrType',
    'Electrical',
    'KitchenQual',
    'Functional',
    'SaleType'
]:
    kaggle_combine_data[column] = kaggle_combine_data[column].fillna(kaggle_combine_data[column].mode()[0])

# %%
kaggle_categorical_treatment = kaggle_combine_data.copy()

# %%
##Function to treat numerical Missing Values 


def knn_impute(dataframe, na_target):
    dataframe = dataframe.copy()
    
    numeric_dataframe = dataframe.select_dtypes(np.number)
    non_na_columns = numeric_dataframe.loc[: ,numeric_dataframe.isna().sum() == 0].columns
    
    y_train = numeric_dataframe.loc[numeric_dataframe[na_target].isna() == False, na_target]
    X_train = numeric_dataframe.loc[numeric_dataframe[na_target].isna() == False, non_na_columns]
    X_test = numeric_dataframe.loc[numeric_dataframe[na_target].isna() == True, non_na_columns]
    
    knn = KNeighborsRegressor()
    knn.fit(X_train, y_train)
    
    predict_y = knn.predict(X_test)
    
    dataframe.loc[dataframe[na_target].isna() == True, na_target] = predict_y
    
    return dataframe

# %%
#treating all the numeric ones and filling with KNN impute 

for column in [
    'LotFrontage',
    'MasVnrArea',
    'BsmtFinSF1',
    'BsmtFinSF2',
    'BsmtUnfSF',
    'TotalBsmtSF',
    'BsmtFullBath',
    'BsmtHalfBath',
    'GarageYrBlt',
    'GarageCars',
    'GarageArea'
]:
    kaggle_categorical_treatment = knn_impute(kaggle_categorical_treatment, column)

# %%
kaggle_categorical_treatment.isna().sum().sum()
# Out:
# 0

# %%
##Feature Engineering 

data_feature = kaggle_categorical_treatment.copy()

# %%
data_feature["SqFtPerRoom"] = data_feature["GrLivArea"] / (data_feature["TotRmsAbvGrd"] +
                                                       data_feature["FullBath"] +
                                                       data_feature["HalfBath"] +
                                                       data_feature["KitchenAbvGr"])

data_feature['Total_Home_Quality'] = data_feature['OverallQual'] + data_feature['OverallCond']

data_feature['Total_Bathrooms'] = (data_feature['FullBath'] + (0.5 * data_feature['HalfBath']) +
                               data_feature['BsmtFullBath'] + (0.5 * data_feature['BsmtHalfBath']))

data_feature["HighQualSF"] = data_feature["1stFlrSF"] + data_feature["2ndFlrSF"]

# %%
# checking SKEWNESS
skew_df = pd.DataFrame(data_feature.select_dtypes(np.number).columns, columns=['Feature'])
skew_df['Skew'] = skew_df['Feature'].apply(lambda feature: scipy.stats.skew(data_feature[feature]))
skew_df['Absolute Skew'] = skew_df['Skew'].apply(abs)
skew_df['Skewed'] = skew_df['Absolute Skew'].apply(lambda x: True if x >= 0.5 else False)
skew_df
# Out:
#                Feature       Skew  Absolute Skew  Skewed
# 0          LotFrontage   1.340751       1.340751    True
# 1              LotArea  12.822431      12.822431    True
# 2          OverallQual   0.197110       0.197110   False
# 3          OverallCond   0.570312       0.570312    True
# 4            YearBuilt  -0.599806       0.599806    True
# 5         YearRemodAdd  -0.451020       0.451020   False
# 6           MasVnrArea   2.603682       2.603682    True
# 7           BsmtFinSF1   1.425516       1.425516    True
# 8           BsmtFinSF2   4.146111       4.146111    True
# 9            BsmtUnfSF   0.919322       0.919322    True
# 10         TotalBsmtSF   1.162806       1.162806    True
# 11            1stFlrSF   1.469604       1.469604    True
# 12            2ndFlrSF   0.861675       0.861675    True
# 13        LowQualFinSF  12.088761      12.088761    True
# 14           GrLivArea   1.269358       1.269358    True
# ...

# %%
#applying log transformation and correcting skewness

for column in skew_df.query("Skewed == True")['Feature'].values:
    data_feature[column] = np.log1p(data_feature[column])

# %%
#making copy of for data dummy process

data_dummy = data_feature.copy()

# %%
#encode and dummy 

data_dummy = pd.get_dummies(data_dummy)

# %%
data_dummy.info()

data_dummy.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2919 entries, 0 to 2918
# Columns: 321 entries, LotFrontage to SaleCondition_Partial
# dtypes: float64(33), int64(6), uint8(282)
# memory usage: 1.7 MB
#        LotFrontage      LotArea  OverallQual  OverallCond    YearBuilt  \
# count  2919.000000  2919.000000  2919.000000  2919.000000  2919.000000
# mean      4.211550     9.094915     6.089072     1.867152     7.586843
# std       0.341238     0.509882     1.409947     0.173171     0.015433
# min       3.091042     7.170888     1.000000     0.693147     7.535297
# 25%       4.110874     8.919854     5.000000     1.791759     7.577890
# 50%       4.262680     9.154193     6.000000     1.791759     7.587817
# 75%       4.395682     9.356257     7.000000     1.945910     7.601902
# max       5.749393    12.279537    10.000000     2.302585     7.606387
#
#        YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2    BsmtUnfSF  \
# ...

# %%
# Performing Scaling SCALING on data dummy 

scaler = StandardScaler()
scaler.fit(data_dummy)

data_dummy = pd.DataFrame(scaler.transform(data_dummy), index=data_dummy.index, columns=data_dummy.columns)

# %%
data_dummy
# Out:
#       LotFrontage   LotArea  OverallQual  OverallCond  YearBuilt  \
# 0       -0.064176 -0.103719     0.646183    -0.435439   1.040634
# 1        0.536077  0.146544    -0.063185     1.906370   0.161526
# 2        0.066112  0.457629     0.646183    -0.435439   0.975922
# 3       -0.295084  0.136301     0.646183    -0.435439  -1.869638
# 4        0.677357  0.922662     1.355551    -0.435439   0.943542
# 5        0.711638  0.902616    -0.772552    -0.435439   0.716427
# 6        0.349325  0.243017     1.355551    -0.435439   1.072966
# 7        0.083054  0.300140     0.646183     0.454875   0.063107
# 8       -0.762960 -0.736443     0.646183    -0.435439  -1.330684
# 9       -0.819875 -0.358667    -0.772552     0.454875  -1.062879
# 10       0.149860  0.448892    -0.772552    -0.435439  -0.200076
# 11       0.711638  0.571753     2.064919    -0.435439   1.105281
# 12       0.372374  0.736378    -0.772552     0.454875  -0.299046
# ...

# %%
##Tranforming TARGET Variable SALES 

plt.figure(figsize=(20, 10))

plt.subplot(1, 2, 1)
sns.distplot(target_sales, kde=True, fit=scipy.stats.norm)
plt.title("Without Log Transform")

plt.subplot(1, 2, 2)
sns.distplot(np.log(target_sales), kde=True, fit=scipy.stats.norm)
plt.xlabel("Log SalePrice")
plt.title("With Log Transform")

plt.show()
# Out:
# C:\Users\shekh\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\shekh\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
Targetlog_sales_price = np.log(target_sales)

# %%
Targetlog_sales_price
# Out:
# 0       12.247694
# 1       12.109011
# 2       12.317167
# 3       11.849398
# 4       12.429216
# 5       11.870600
# 6       12.634603
# 7       12.206073
# 8       11.774520
# 9       11.678440
# 10      11.771436
# 11      12.751300
# 12      11.877569
# 13      12.540758
# 14      11.964001
# 15      11.790557
# 16      11.911702
# 17      11.407565
# 18      11.976659
# 19      11.842229
# 20      12.692503
# 21      11.845103
# 22      12.345835
# 23      11.774520
# 24      11.944708
# 25      12.454104
# 26      11.811547
# 27      12.631340
# 28      12.242887
# 29      11.134589
# 30      10.596635
# 31      11.914048
# 32      12.100156
# 33      12.016726
# 34      12.533576
# 35      12.641097
# 36      11.884489
# 37      11.938193
# 38      11.599103
# 39      11.314475
# 40      11.982929
# 41      12.043554
# 42      11.877569
# 43      11.777211
# 44      11.856515
#           ...
# 1415    12.077671
# 1416    11.715866
# 1417    12.736701
# 1418    11.728037
# ...

# %%
##SPLIT DATA AND PRODUCING FINAL FOR MODEL 

train_final = data_dummy.loc[:train_data.index.max(), :].copy()
test_final = data_dummy.loc[train_data.index.max() + 1:, :].reset_index(drop=True).copy()

# %%
train_final.to_csv('traindatafinal_anuj.csv')
test_final.to_csv('testdatafinal_anuj.csv')

# %%
from sklearn.linear_model import Lasso

# %%
##ridge model parameters 

ridge_parameters = {
    'alpha': 631.1412445239156
}

# %%
#STUDY FOR RIDGE PARAM VALUE 
def objective(trail):
    alpha = trail.suggest_log_uniform('alpha_1' 1e-8,10.00)

# %%
#Defining Ridge Regression Model

models = {
    "ridge": Ridge(**ridge_parameters),
}

# %%
## Training Ridge Regression Model

for name, model in models.items():
    model.fit(train_final, Targetlog_sales_price)
    print(name + " trained.")
# Out:
# ridge trained.

# %%
##Evaluating our MODEL 

results = {}

kf = KFold(n_splits=10)

for name, model in models.items():
    result = np.exp(np.sqrt(-cross_val_score(model, train_final, Targetlog_sales_price, scoring='neg_mean_squared_error', cv=kf)))
    results[name] = result

# %%
results
# Out:
# {'ridge': array([1.12338036, 1.1053367 , 1.12412145, 1.16994036, 1.15545706,
#         1.12173273, 1.1260853 , 1.1037994 , 1.18188318, 1.13358299])}

# %%
for name, result in results.items():
    print("----------\n" + name)
    print(np.mean(result))
    print(np.std(result))
# Out:
# ----------
# ridge
# 1.1345319533871139
# 0.02489861334742041

# %%
#FINAL PREDICTIONS 

#Doing exponentional to converting back to original values 

final_predictions_ridge = np.exp(models['ridge'].predict(test_final))

# %%
final_predictions_ridge
# Out:
# array([121054.10990748, 158306.85279324, 181551.30780357, ...,
#        161322.18245809, 116399.39938879, 215717.67892527])

# %%
anujsubmission_ridgefinal = pd.concat([test_ids, pd.Series(final_predictions_ridge, name='SalePrice')], axis=1)
anujsubmission_ridgefinal
# Out:
#         Id      SalePrice
# 0     1461  121054.109907
# 1     1462  158306.852793
# 2     1463  181551.307804
# 3     1464  197023.855478
# 4     1465  195279.586419
# 5     1466  171574.902386
# 6     1467  169858.472462
# 7     1468  164174.932961
# 8     1469  187973.336114
# 9     1470  121638.537025
# 10    1471  176366.142195
# 11    1472   98043.123731
# 12    1473   98302.694820
# 13    1474  142810.299171
# 14    1475  111863.450653
# 15    1476  353801.512752
# 16    1477  241797.621048
# 17    1478  294350.630646
# 18    1479  295485.950126
# 19    1480  453068.998770
# 20    1481  329859.420734
# 21    1482  214005.595264
# 22    1483  178532.012380
# 23    1484  165590.116379
# 24    1485  193387.530842
# 25    1486  195952.639457
# 26    1487  337102.352432
# 27    1488  224124.719977
# 28    1489  194644.057356
# 29    1490  237149.969315
# 30    1491  194937.674487
# 31    1492   93115.472531
# 32    1493  178296.990497
# 33    1494  291269.847631
# ...

# %%
# Out:
#         Id      SalePrice
# 0     1461  166716.642887
# 1     1462  166716.642887
# 2     1463  166716.642887
# 3     1464  166716.642887
# 4     1465  166716.642887
# 5     1466  166716.642887
# 6     1467  166716.642887
# 7     1468  166716.642887
# 8     1469  166716.642887
# 9     1470  166716.642887
# 10    1471  166716.642887
# 11    1472  166716.642887
# 12    1473  166716.642887
# 13    1474  166716.642887
# 14    1475  166716.642887
# 15    1476  166716.642887
# 16    1477  166716.642887
# 17    1478  166716.642887
# 18    1479  166716.642887
# 19    1480  166716.642887
# 20    1481  166716.642887
# 21    1482  166716.642887
# 22    1483  166716.642887
# 23    1484  166716.642887
# 24    1485  166716.642887
# 25    1486  166716.642887
# 26    1487  166716.642887
# 27    1488  166716.642887
# 28    1489  166716.642887
# 29    1490  166716.642887
# 30    1491  166716.642887
# 31    1492  166716.642887
# 32    1493  166716.642887
# 33    1494  166716.642887
# ...

# %%
anujsubmission_ridgefinal.to_csv('./anujsubmissionridge_final.csv', index=False, header=True)

# %%
# Out:
# Ridge score on training set:  190438.81920484157

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-955ac4e1a074> in <module>()
# ----> 1 _, _, lasso_clf = cv_train_and_evaluate(lasso, param_grid, x_train_lasso, y_train_lasso, x_val_lasso, y_val_lasso, 'Lasso')
#
# NameError: name 'cv_train_and_evaluate' is not defined

# %%
# The error metric: RMSE on the log of the sale prices.
from sklearn.metrics import mean_squared_error
def rmse(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

# %%
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_squared_error

crossvalidation_alpha = 0.00099

regr = Lasso(alpha=crossvalidation_alpha, max_iter=50000)

regr.fit(train_final, Targetlog_sales_price)

# Run prediction on training set to get a rough idea of how well it does.
y_pred = regr.predict(train_final)
y_test = Targetlog_sales_price
print("Lasso score on training set: ", rmse(y_test, y_pred))
# Run prediction on the Kaggle test set.
y_pred_lasso = regr.predict(test_final)
# Out:
# Lasso score on training set:  0.09420628599469442

# %%
y_pred_lasso_final = np.exp(y_pred_lasso)

# %%
anujsubmission_lassofinal = pd.concat([test_ids, pd.Series(y_pred_lasso_final, name='SalePrice')], axis=1)

# %%
anujsubmission_lassofinal.to_csv('./anujlasso_final1.csv', index=False, header=True)

# %%
anujsubmission_lassofinal
# Out:
#         Id      SalePrice
# 0     1461  123630.002888
# 1     1462  155805.485361
# 2     1463  185971.770109
# 3     1464  197273.609772
# 4     1465  203264.568982
# 5     1466  172424.053949
# 6     1467  177846.890518
# 7     1468  161088.836966
# 8     1469  198759.131410
# 9     1470  120812.385492
# 10    1471  177730.925954
# 11    1472   98075.593337
# 12    1473   96440.036365
# 13    1474  143074.384519
# 14    1475  109979.692190
# 15    1476  365121.749795
# 16    1477  251452.434443
# 17    1478  309454.607649
# 18    1479  302298.488132
# 19    1480  478760.736400
# 20    1481  330738.221193
# 21    1482  213760.921957
# 22    1483  181493.564231
# 23    1484  160091.339731
# 24    1485  192481.914077
# 25    1486  192135.631634
# 26    1487  346351.691293
# 27    1488  232557.157618
# 28    1489  196248.076019
# 29    1490  242712.675971
# 30    1491  194172.718955
# 31    1492   94075.527782
# 32    1493  187339.656116
# 33    1494  292619.400279
# ...
